# %%
from lib.project_5_ADH import load_data_from_database, make_data_dict, general_model, general_transformer
from numpy import arange
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
import pandas as pd
import numpy as np

# %% [markdown]
# # Step 3 - Build Model

# %% [markdown]
# ### Domain and Data
#
# The data, referred to as Madelon, is 2000 rows and 500 features (1 index, 1 target). The dataset is artificial with a two-class target (-1, 1) with continuous input (parameter) variables.
#
# ### Problem Statement
#
# Implement a machine learning pipeline using Logisitic Regression and KNeighborsClassifier while transforming the data using SelectKBest.
#
# ### Solution Statement
#
# Provide a jupyter notebook with a pipeline (with regularization) that will show how the Logistic Regression and KNeighbors models work. Check how many salient features each use.
#
# ### Metric
#
# I would like to reduce the amount of salient features that I determined in the prior workbook (step 2).
#
# ### Benchmark
#
# I would like to beat my test score from step 1 of ~55%.

# %% [markdown]
# ## Implementation
#
# Implement the following code pipeline using the functions you write in `lib/project_5.py`.

# %% [markdown]
# <img src="assets/build_model.png" width="600px">

# %%
madelon_df = load_data_from_database('dsi_student', 'correct horse battery staple', 'joshuacook.me', 
                                     '5432', 'dsi', 'madelon')

# %%
madelon_df.head()
# Out:
#    index  feat_000  feat_001  feat_002  feat_003  feat_004  feat_005  \
# 0      0       485       477       537       479       452       471
# 1      1       483       458       460       487       587       475
# 2      2       487       542       499       468       448       471
# 3      3       480       491       510       485       495       472
# 4      4       484       502       528       489       466       481
#
#    feat_006  feat_007  feat_008  ...    feat_491  feat_492  feat_493  \
# 0       491       476       475  ...         481       477       485
# 1       526       479       485  ...         478       487       338
# 2       442       478       480  ...         481       492       650
# 3       417       474       502  ...         480       474       572
# 4       402       478       487  ...         479       452       435
#
#    feat_494  feat_495  feat_496  feat_497  feat_498  feat_499  label
# 0       511       485       481       479       475       496     -1
# 1       513       486       483       492       510       517     -1
# 2       506       501       480       489       499       498     -1
# 3       454       469       475       482       494       461      1
# 4       486       508       481       504       495       511      1
#
# [5 rows x 502 columns]

# %%
data_dict = make_data_dict(madelon_df, random_state = 40, test_size = 0.20)

# %%
data_dict = general_transformer(StandardScaler(), data_dict)

# %%
data_dict = general_transformer(SelectKBest(), data_dict)

# %%
K_best_selection = data_dict['processes'][1]

# %%
np.where(K_best_selection.get_support())
# Out:
# (array([ 48,  64, 105, 128, 241, 336, 338, 442, 472, 475]),)

# %%
LR_scores = general_model(LogisticRegression(), data_dict)
LR_scores['train score'], LR_scores['test score']
# Out:
# (0.61499999999999999, 0.59750000000000003)

# %%
data_dict['processes'][2].coef_.flatten()
# SelectKBest only chose 10!
# Out:
# array([ 0.13579799, -0.11706957,  0.05055887,  0.15962245,  0.16447294,
#         0.21886389,  0.20087084, -0.31649912,  0.2762322 ,  0.40462379])

# %%
KNN_scores = general_model(KNeighborsClassifier(), data_dict)
KNN_scores['train score'], KNN_scores['test score']
# Out:
# (0.91062500000000002, 0.86250000000000004)

# %%
lg_param_grid = {'C': [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0]}
GSCV_LR_scores = general_model(GridSearchCV(LogisticRegression(),lg_param_grid), data_dict)
GSCV_LR_scores['train score'], GSCV_LR_scores['test score']
# Out:
# (0.61312500000000003, 0.59999999999999998)

# %%
GSCV_LR = data_dict['processes'][4]

# %%
pd.DataFrame(GSCV_LR.cv_results_)
# best estimator is c = 0.1
# Out:
#    mean_fit_time  mean_score_time  mean_test_score  mean_train_score param_C  \
# 0       0.003468         0.000451         0.593750          0.590936  0.0001
# 1       0.002825         0.000361         0.591875          0.596875   0.001
# 2       0.002969         0.000360         0.600625          0.608437    0.01
# 3       0.003262         0.000401         0.603750          0.615623     0.1
# 4       0.003551         0.000368         0.600625          0.616248       1
# 5       0.003965         0.000516         0.596250          0.610938      10
# 6       0.004005         0.000395         0.595625          0.610313     100
# 7       0.003827         0.000376         0.595625          0.610313    1000
#
#            params  rank_test_score  split0_test_score  split0_train_score  \
# 0  {u'C': 0.0001}                7           0.595506            0.585366
# 1   {u'C': 0.001}                8           0.586142            0.596623
# 2    {u'C': 0.01}                2           0.580524            0.606942
# 3     {u'C': 0.1}                1           0.578652            0.607880
# 4     {u'C': 1.0}                2           0.578652            0.610694
# 5    {u'C': 10.0}                4           0.576779            0.611632
# 6   {u'C': 100.0}                5           0.576779            0.611632
# 7  {u'C': 1000.0}                5           0.576779            0.611632
#
#    split1_test_score  split1_train_score  split2_test_score  \
# 0           0.594747            0.596064           0.590994
# 1           0.590994            0.598875           0.598499
# 2           0.613508            0.602624           0.607880
# 3           0.611632            0.617619           0.621013
# 4           0.609756            0.614808           0.613508
# 5           0.604128            0.608247           0.607880
# 6           0.604128            0.606373           0.606004
# 7           0.604128            0.606373           0.606004
#
#    split2_train_score  std_fit_time  std_score_time  std_test_score  \
# 0            0.591378      0.000387        0.000066        0.001972
# 1            0.595127      0.000262        0.000006        0.005084
# 2            0.615745      0.000101        0.000006        0.014411
# 3            0.621368      0.000198        0.000033        0.018172
# 4            0.623243      0.000114        0.000013        0.015627
# 5            0.612933      0.000702        0.000194        0.013866
# 6            0.612933      0.000264        0.000032        0.013361
# 7            0.612933      0.000152        0.000014        0.013361
#
#    std_train_score
# 0         0.004379
# 1         0.001541
# 2         0.005460
# 3         0.005685
# 4         0.005223
# 5         0.001975
# 6         0.002836
# 7         0.002836

# %%
knn_param_grid = {'n_neighbors': [x for x in arange(3, 52, 2)]}
GSCV_knn_scores = general_model(GridSearchCV(KNeighborsClassifier(),knn_param_grid), data_dict)
GSCV_knn_scores['train score'], GSCV_knn_scores['test score']
# Out:
# (0.91062500000000002, 0.86250000000000004)

# %%
GSCV_KNN = data_dict['processes'][5]

# %%
pd.DataFrame(GSCV_KNN.cv_results_)
# best estimator is neighbors = 5
# Out:
#     mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 0        0.002745         0.007738         0.848750          0.931246
# 1        0.002333         0.008025         0.850000          0.903437
# 2        0.002250         0.008466         0.844375          0.890624
# 3        0.002140         0.008552         0.839375          0.874374
# 4        0.002169         0.008288         0.826250          0.871249
# 5        0.002156         0.008821         0.821875          0.863436
# 6        0.002154         0.009115         0.815625          0.856873
# 7        0.002197         0.009526         0.816875          0.848749
# 8        0.003361         0.012593         0.811250          0.844061
# 9        0.003120         0.011371         0.808750          0.834998
# 10       0.002603         0.013686         0.802500          0.829686
# 11       0.002285         0.011147         0.799375          0.829685
# 12       0.002240         0.013060         0.800625          0.824373
# 13       0.002531         0.013250         0.791875          0.824061
# 14       0.002378         0.012918         0.785625          0.818125
# 15       0.002920         0.013328         0.781875          0.814688
# 16       0.002876         0.015768         0.780000          0.809061
# 17       0.002385         0.017896         0.778750          0.804374
# 18       0.002615         0.015808         0.773750          0.800623
# 19       0.002270         0.014470         0.768125          0.795310
# 20       0.002139         0.015650         0.766250          0.791249
# 21       0.002219         0.014655         0.766250          0.783747
# 22       0.002253         0.014922         0.759375          0.784685
# 23       0.002168         0.014980         0.756875          0.779374
# 24       0.002216         0.015915         0.746875          0.776562
#
#    param_n_neighbors                params  rank_test_score  \
# 0                  3   {u'n_neighbors': 3}                2
# 1                  5   {u'n_neighbors': 5}                1
# 2                  7   {u'n_neighbors': 7}                3
# 3                  9   {u'n_neighbors': 9}                4
# 4                 11  {u'n_neighbors': 11}                5
# 5                 13  {u'n_neighbors': 13}                6
# 6                 15  {u'n_neighbors': 15}                8
# 7                 17  {u'n_neighbors': 17}                7
# 8                 19  {u'n_neighbors': 19}                9
# 9                 21  {u'n_neighbors': 21}               10
# 10                23  {u'n_neighbors': 23}               11
# 11                25  {u'n_neighbors': 25}               13
# 12                27  {u'n_neighbors': 27}               12
# 13                29  {u'n_neighbors': 29}               14
# 14                31  {u'n_neighbors': 31}               15
# 15                33  {u'n_neighbors': 33}               16
# 16                35  {u'n_neighbors': 35}               17
# 17                37  {u'n_neighbors': 37}               18
# 18                39  {u'n_neighbors': 39}               19
# 19                41  {u'n_neighbors': 41}               20
# 20                43  {u'n_neighbors': 43}               21
# 21                45  {u'n_neighbors': 45}               21
# 22                47  {u'n_neighbors': 47}               23
# 23                49  {u'n_neighbors': 49}               24
# 24                51  {u'n_neighbors': 51}               25
#
#     split0_test_score  split0_train_score  split1_test_score  \
# 0            0.853933            0.919325           0.840525
# 1            0.861423            0.903377           0.834897
# 2            0.852060            0.888368           0.838649
# 3            0.844569            0.869606           0.840525
# 4            0.833333            0.867730           0.833021
# 5            0.827715            0.860225           0.833021
# 6            0.822097            0.848968           0.816135
# 7            0.820225            0.845216           0.818011
# 8            0.816479            0.837711           0.808630
# 9            0.810861            0.828330           0.810507
# 10           0.797753            0.825516           0.810507
# 11           0.794007            0.821764           0.808630
# 12           0.799625            0.817073           0.801126
# 13           0.792135            0.820826           0.789869
# 14           0.792135            0.818011           0.782364
# 15           0.790262            0.815197           0.780488
# 16           0.788390            0.803940           0.782364
# 17           0.788390            0.800188           0.784240
# 18           0.779026            0.792683           0.780488
# 19           0.773408            0.787992           0.774859
# 20           0.765918            0.787054           0.780488
# 21           0.773408            0.774859           0.778612
# 22           0.762172            0.775797           0.765478
# 23           0.762172            0.774859           0.765478
# 24           0.745318            0.774859           0.752345
#
#     split1_train_score  split2_test_score  split2_train_score  std_fit_time  \
# 0             0.947516           0.851782            0.926898      0.000563
# 1             0.904405           0.853659            0.902530      0.000018
# 2             0.893158           0.842402            0.890347      0.000105
# 3             0.873477           0.833021            0.880037      0.000033
# 4             0.870665           0.812383            0.875351      0.000024
# 5             0.863168           0.804878            0.866917      0.000013
# 6             0.859419           0.808630            0.862231      0.000015
# 7             0.846298           0.812383            0.854733      0.000038
# 8             0.843486           0.808630            0.850984      0.001095
# 9             0.830366           0.804878            0.846298      0.000785
# 10            0.824742           0.799250            0.838800      0.000495
# 11            0.828491           0.795497            0.838800      0.000252
# 12            0.826617           0.801126            0.829428      0.000142
# 13            0.824742           0.793621            0.826617      0.000413
# 14            0.818182           0.782364            0.818182      0.000202
# 15            0.812559           0.774859            0.816307      0.000427
# 16            0.808810           0.769231            0.814433      0.000566
# 17            0.807873           0.763602            0.805061      0.000330
# 18            0.805061           0.761726            0.804124      0.000388
# 19            0.804124           0.756098            0.793814      0.000211
# 20            0.799438           0.752345            0.787254      0.000043
# 21            0.794752           0.746717            0.781631      0.000121
# 22            0.792877           0.750469            0.785380      0.000042
# 23            0.785380           0.742964            0.777882      0.000023
# 24            0.782568           0.742964            0.772259      0.000097
#
#     std_score_time  std_test_score  std_train_score
# 0         0.001857        0.005879         0.011913
# 1         0.000891        0.011135         0.000766
# 2         0.000849        0.005651         0.001966
# 3         0.000529        0.004785         0.004306
# 4         0.000261        0.009802         0.003139
# 5         0.000256        0.012207         0.002738
# 6         0.000103        0.005511         0.005706
# 7         0.000107        0.003301         0.004254
# 8         0.002558        0.003701         0.005434
# 9         0.001534        0.002740         0.008033
# 10        0.002841        0.005692         0.006452
# 11        0.000099        0.006570         0.007006
# 12        0.001914        0.000707         0.005288
# 13        0.000994        0.001542         0.002413
# 14        0.000881        0.004607         0.000080
# 15        0.000508        0.006365         0.001572
# 16        0.002754        0.007999         0.004287
# 17        0.003153        0.010839         0.003175
# 18        0.001082        0.008519         0.005627
# 19        0.000559        0.008521         0.006670
# 20        0.001113        0.011488         0.005791
# 21        0.000407        0.013968         0.008258
# 22        0.000307        0.006438         0.006990
# 23        0.000083        0.009924         0.004423
# 24        0.000613        0.003984         0.004378

# %% [markdown]
# ## Results
#
# KNearestNeighbors (KNN) immensely outperformed Logisitic Regression (LR). Train and test scores for KNN and LR are (0.91, 0.86) and (0.61, 0.60), respectively, when a grid search is performed.
